# %%
from rich.pretty import pprint
from kbac.loaders import MatrixScriptLoader

# %%
loader = MatrixScriptLoader()
documents = loader.load()

pprint(documents[:10])
# Out:
# 100%|██████████| 133/133 [00:00<00:00, 157.18it/s]
# [
# │   Document(
# │   │   text='so close it has no boundaries. A blinding cursor pulses in the electric darkness like a heart coursing with phosphorous light, burning beneath the derma of black-neon glass. A PHONE begins to RING, we hear it as though we were making the call.  The cursor continues to throb, relentlessly patient, until --',
# │   │   metadata={
# │   │   │   'text_type': 'scene_description',
# │   │   │   'scene_description_id': 'b07ce375484deb12a717294c704cafa7',
# │   │   │   'character': None,
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 2
# │   │   }
# │   ),
# │   Document(
# │   │   text='Yeah?',
# │   │   metadata={
# │   │   │   'text_type': 'dialog',
# │   │   │   'character': 'MAN',
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'scene_description_id': 'b07ce375484deb12a717294c704cafa7',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 4
# │   │   }
# │   ),
# │   Document(
# │   │   text='Data now slashes across the screen, information flashing faster then we can read:  "Call trans opt:  received. 2-19-98 13:24:18  REC:Log>."',
# │   │   metadata={
# │   │   │   'text_type': 'scene_description',
# │   │   │   'scene_description_id': 'fd40644ac96352a18c5c3813511425ed',
# │   │   │   'character': None,
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 5
# │   │   }
# │   ),
# │   Document(
# │   │   text='Is everything in place?',
# │   │   metadata={
# │   │   │   'text_type': 'dialog',
# │   │   │   'character': 'WOMAN',
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'scene_description_id': 'fd40644ac96352a18c5c3813511425ed',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 7
# │   │   }
# │   ),
# │   Document(
# │   │   text='On screen:  "Trace program:  running." We listen to the phone conversation as though we were on a third line.  The man\'s name is Cypher.  The woman, Trinity.',
# │   │   metadata={
# │   │   │   'text_type': 'scene_description',
# │   │   │   'scene_description_id': 'a6b6e773b6583ff2f7f6df0f602ddf47',
# │   │   │   'character': None,
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 8
# │   │   }
# │   ),
# │   Document(
# │   │   text='I said, is everything in place?',
# │   │   metadata={
# │   │   │   'text_type': 'dialog',
# │   │   │   'character': 'TRINITY',
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'scene_description_id': 'a6b6e773b6583ff2f7f6df0f602ddf47',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 10
# │   │   }
# │   ),
# │   Document(
# │   │   text='The entire screen with racing columns of numbers. Shimmering like green-electric rivers, they rush at a 10-digit phone number in the top corner.',
# │   │   metadata={
# │   │   │   'text_type': 'scene_description',
# │   │   │   'scene_description_id': 'eee7b696450ba836fda40235ae50b2d2',
# │   │   │   'character': None,
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 11
# │   │   }
# │   ),
# │   Document(
# │   │   text="You weren't supposed to relieve me.",
# │   │   metadata={
# │   │   │   'text_type': 'dialog',
# │   │   │   'character': 'CYPHER',
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'scene_description_id': 'eee7b696450ba836fda40235ae50b2d2',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 13
# │   │   }
# │   ),
# │   Document(
# │   │   text='I know but I felt like taking a shift.',
# │   │   metadata={
# │   │   │   'text_type': 'dialog',
# │   │   │   'character': 'TRINITY',
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'scene_description_id': 'eee7b696450ba836fda40235ae50b2d2',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 15
# │   │   }
# │   ),
# │   Document(
# │   │   text='The area code is identified.  The first three numbers suddenly fixed, leaving only seven flowing columns.',
# │   │   metadata={
# │   │   │   'text_type': 'scene_description',
# │   │   │   'scene_description_id': 'e2e7aebac21689e7352771b8a4b48f77',
# │   │   │   'character': None,
# │   │   │   'location': 'ON COMPUTER SCREEN',
# │   │   │   'page_number': 1,
# │   │   │   'line_number': 16
# │   │   }
# │   )
# ]
